# %%
import nltk
import numpy as np
nltk.download('movie_reviews')

from nltk.corpus import movie_reviews
from sklearn.model_selection import train_test_split
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Embedding, Flatten
from tensorflow.keras.utils import to_categorical
# Out:
# [nltk_data] Downloading package movie_reviews to
# [nltk_data]     C:\Users\kgliv\AppData\Roaming\nltk_data...
# [nltk_data]   Package movie_reviews is already up-to-date!

# %%
documents = []
labels = []

for fileid in movie_reviews.fileids():
    documents.append(movie_reviews.raw(fileid))
    labels.append(1 if movie_reviews.categories(fileid)[0] == 'pos' else 0)

# Train-test split
X_train, X_test, y_train, y_test = train_test_split(
    documents, labels, test_size=0.2, random_state=42)

# %%
X_train, X_test, y_train, y_test = train_test_split(
    documents, labels, test_size=0.2, random_state=42)

# Tokenization
vocab_size = 10000
max_len = 200

tokenizer = Tokenizer(num_words=vocab_size)
tokenizer.fit_on_texts(X_train)

X_train_seq = tokenizer.texts_to_sequences(X_train)
X_test_seq = tokenizer.texts_to_sequences(X_test)

X_train_pad = pad_sequences(X_train_seq, maxlen=max_len)
X_test_pad = pad_sequences(X_test_seq, maxlen=max_len)

y_train = np.array(y_train)
y_test = np.array(y_test)

# %%
from nltk.corpus import brown

# Get sentences
sentences = brown.sents()

# Convert to text
texts = [' '.join(sent) for sent in sentences[:5000]]

tokenizer = Tokenizer(num_words=10000)
tokenizer.fit_on_texts(texts)

sequences = tokenizer.texts_to_sequences(texts)

# %%
# Create training sequences
input_sequences = []
for seq in sequences:
    for i in range(1, len(seq)):
        input_sequences.append(seq[:i+1])

input_sequences = pad_sequences(input_sequences)

X = input_sequences[:, :-1]
y = input_sequences[:, -1]

y = to_categorical(y, num_classes=10000)

# %%
from tensorflow.keras.layers import LSTM

model_lm = Sequential([
    Embedding(10000, 64, input_length=X.shape[1]),
    LSTM(100),
    Dense(10000, activation='softmax')
])
# Out:
# C:\Users\kgliv\AppData\Local\Programs\Python\Python313\Lib\site-packages\keras\src\layers\core\embedding.py:100: UserWarning: Argument `input_length` is deprecated. Just remove it.
#   warnings.warn(

# %%
model_lm.compile(
    loss='categorical_crossentropy',
    optimizer='adam',
    metrics=['accuracy']
)

model_lm.fit(
    X, y,
    epochs=5,
    batch_size=64
)
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# Cell In[7], line 7
#       1 model_lm.compile(
#       2     loss='categorical_crossentropy',
#       3     optimizer='adam',
#       4     metrics=['accuracy']
#       5 )
# ----> 7 model_lm.fit(
#       8     X, y,
#       9     epochs=5,
#      10     batch_size=64
#      11 )
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\keras\src\utils\traceback_utils.py:122, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     119     filtered_tb = _process_traceback_frames(e.__traceback__)
#     120     # To get the full stack trace, call:
#     121     # `keras.config.disable_traceback_filtering()`
# --> 122     raise e.with_traceback(filtered_tb) from None
#     123 finally:
#     124     del filtered_tb
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\tensorflow\python\framework\constant_op.py:96, in convert_to_eager_tensor(value, ctx, dtype)
#      76 """Converts the given `value` to an `EagerTensor`.
#      77
#      78 Note that this function could return cached copies of created constants for
#    (...)     90   TypeError: if `dtype` is not compatible with the type of t.
#      91 """
#      92 if isinstance(value, np.ndarray):
#      93   # Make a copy explicitly because the EagerTensor might share the underlying
#      94   # memory with the input array. Without this copy, users will be able to
#      95   # modify the EagerTensor after its creation by changing the input array.
# ---> 96   value = value.copy()
#      97 if isinstance(value, ops.EagerTensor):
#      98   if dtype is not None and value.dtype != dtype:
#
# MemoryError: Unable to allocate 3.37 GiB for an array with shape (90449, 10000) and data type float32
